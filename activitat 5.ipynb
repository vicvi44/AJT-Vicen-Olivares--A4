# %% [markdown]
# Exercici 1

# %%
class song():
    def __init__(self,titol,autor,durada):
        self.titol=titol
        self.autor=autor
        self.durada=durada
    def info(self):
        return f"{self.titol}-{self.autor}({self.durada})"

song1=song("love song", "future","203 segons")
song1.info()

class playlist:

    def __init__ ( self, song_list):
        self.song_list = song_list  
        song_list = []

    def afegir_canco ( self, canco):
        self.song_list.append(canco)

    def durada_total ( self):
        total = 0
        for i in self.song_list:
            total = total+i.durada
        return total

    def mostrar_playlist ( self):
        for n in self.song_list:
            print ( n.info())

    def canco_mes_llarga ( self):
        canco_mes_llarga = self.song_list[0]
        for x in self.song_list:
            if x.durada > canco_mes_llarga.durada:
                canco_mes_llarga = x
        return canco_mes_llarga.info()


song1=song("love song", "future",203 )

canco2 = song ( "scream and shout", "Britney spears", 240)

playlist1 = playlist ( [canco1, canco2])

canco3 = song ( "", "Jay-Z", 4.36)  

playlist1.afegir_canco ( canco3)

print ( playlist1.durada_total())
print ( playlist1.canco_mes_llarga())
playlist1.mostrar_playlist()

# %%
class playlist():
    def __init__(self,song_list):
        self.song_list=[]
    def afegir_canço(song)

# %%
class personatge():
    jugador=personatge("jugador1", 10,2,1)
    enemic=personatge("enemic",4,3,1)
    def __init__(self,nom,vida,força,nivell):
        self.nom=nom
        self.vida=vida
        self.força=força
        self.nivell=nivell
    def atacar(self,enemic):
        enemic.vida=enemic.vida - self.força
        
    def pujar_nivell(self):
        self.vida=self.vida+1
        self.força=self.força+5
        self.nivell=self.nivell+1

    def esta_viu(self):
        if self.vida>0:
            return True
    def __str__(self):
        return f"Nom:{self.nom}, Vida:{self.vida}\nForça:{self.força}, Nivell:{self.nivell}"
    def combat(self,enemic):
        while self.vida or enemic.vida > 0:
            self.atacar(enemic,self)
            enemic.atacar(enemic,self)
            if enemic.vida<=0:
                print("Has guanyat!!!")
                self.pujar_nivell(self)
            else:
                print("Has perdut")
